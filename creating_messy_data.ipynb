# %%
import pandas as pd
import numpy as np

# Creating messy dataset
data = {
    'Transaction_ID': ['TX01', 'TX02', 'tx03 ', ' TX04', np.nan, 'TX06', 'TX06'],
    'Customer_Name': ['JOHN DOE', 'jane smith', '  alice ', 'Bob', 'Charlie', np.nan, 'DAVID '],
    'Purchase_Date': ['2023-01-15', '15/01/2023', 'invalid_date_here', '20230117', np.nan, '2023-01-18', '2023-01-18'],
    'Item_Price': ['$15.99', '20.50', 'FREE', '$ 12.00', '100', np.nan, '$45.00']
}

df_messy = pd.DataFrame(data)

# Exporting to CSV
df_messy.to_csv('messy_client_data.csv', index=False)
print("Client file 'messy_client_data.csv' has been generated and saved!")
display(df_messy)
# Out:
# Client file 'messy_client_data.csv' has been generated and saved!
#   Transaction_ID Customer_Name      Purchase_Date Item_Price
# 0           TX01      JOHN DOE         2023-01-15     $15.99
# 1           TX02    jane smith         15/01/2023      20.50
# 2          tx03         alice   invalid_date_here       FREE
# 3           TX04           Bob           20230117    $ 12.00
# 4            NaN       Charlie                NaN        100
# 5           TX06           NaN         2023-01-18        NaN
# 6           TX06        DAVID          2023-01-18     $45.00
